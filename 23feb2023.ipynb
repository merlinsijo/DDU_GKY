# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from pydataset import data

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().mean()*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
df.fillna({"age":29},inplace=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  29.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
 df.dropna(inplace=True)

# %%
df.isnull().mean()*100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# deck           0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %%
x=df[['age']]
x
# Out:
#       age
# 1    38.0
# 3    35.0
# 6    54.0
# 10    4.0
# 11   58.0
# ..    ...
# 871  47.0
# 872  33.0
# 879  56.0
# 887  19.0
# 889  26.0
#
# [182 rows x 1 columns]

# %%
x_transformed=minmax.fit_transform(x)
x_transformed
# Out:
# array([[0.46889226],
#        [0.43095599],
#        [0.67121902],
#        [0.0389479 ],
#        [0.72180071],
#        [0.41831057],
#        [0.34243804],
#        [0.22862924],
#        [0.60799191],
#        [0.81031866],
#        [0.55741022],
#        [0.35508346],
#        [0.30450177],
#        [0.27921093],
#        [0.57005564],
#        [0.8861912 ],
#        [0.27921093],
#        [0.25392008],
#        [0.58270106],
#        [0.29185635],
#        [0.39934244],
#        [0.67121902],
#        [0.22862924],
#        [0.45624684],
#        [0.29185635],
#        [0.44992413],
#        [0.2665655 ],
#        [0.75973698],
#        [0.69650986],
#        [0.62063733],
#        [0.00101163],
#        [0.02630248],
#        [0.5447648 ],
#        [0.72180071],
#        [0.01365706],
#        [0.49418311],
#        [0.3803743 ],
#        [0.39301973],
#        [0.46889226],
#        [0.43095599],
#        [0.5447648 ],
#        [0.45624684],
#        [0.35508346],
#        [0.7723824 ],
#        [0.36772888],
#        [0.64592817],
#        [0.49418311],
#        [0.72180071],
#        [0.43095599],
#        [0.45624684],
#        [0.78502782],
#        [0.22862924],
#        [0.44360142],
#        [0.01365706],
#        [0.62063733],
#        [0.        ],
#        [0.20333839],
#        [0.36772888],
#        [0.29185635],
#        [0.21598381],
#        [0.3803743 ],
#        [0.49418311],
#        [0.44360142],
#        [0.44360142],
#        [0.19069297],
#        [0.56373293],
#        [0.46889226],
#        [0.35508346],
#        [0.50682853],
#        [0.01365706],
#        [0.29185635],
#        [0.29185635],
#        [0.2665655 ],
#        [0.74709155],
#        [0.29185635],
#        [0.30450177],
#        [0.32979262],
#        [0.44360142],
#        [0.27921093],
#        [0.29185635],
#        [0.40566515],
#        [0.39301973],
#        [0.34243804],
#        [0.62063733],
#        [0.16540212],
#        [0.79767324],
#        [0.0389479 ],
#        [0.64592817],
#        [0.36772888],
#        [0.60799191],
#        [0.81031866],
#        [0.59534648],
#        [0.58270106],
#        [0.27921093],
#        [0.30450177],
#        [0.43095599],
#        [0.72180071],
#        [0.68386444],
#        [0.67121902],
#        [0.30450177],
#        [0.19069297],
#        [0.21598381],
#        [0.44360142],
#        [0.58270106],
#        [0.41831057],
#        [0.36772888],
#        [0.5447648 ],
#        [0.55741022],
#        [0.2665655 ],
#        [0.44360142],
#        [0.62063733],
#        [0.20333839],
#        [0.59534648],
#        [0.48153768],
#        [0.6585736 ],
#        [0.44360142],
#        [0.48153768],
#        [0.48153768],
#        [0.44360142],
#        [0.21598381],
#        [0.74709155],
#        [0.64592817],
#        [0.60799191],
#        [0.49418311],
#        [0.0389479 ],
#        [0.51947395],
#        [0.75973698],
#        [0.25392008],
#        [1.        ],
#        [0.39301973],
#        [0.29185635],
#        [0.59534648],
#        [0.69650986],
#        [0.72180071],
#        [0.58270106],
#        [0.3803743 ],
#        [0.44360142],
#        [0.32979262],
#        [0.17804755],
#        [0.3803743 ],
#        [0.60799191],
#        [0.51947395],
#        [0.21598381],
#        [0.43095599],
#        [0.51947395],
#        [0.29185635],
#        [0.59534648],
#        [0.22862924],
#        [0.46889226],
#        [0.32979262],
#        [0.32979262],
#        [0.35508346],
#        [0.43095599],
#        [0.44360142],
#        [0.25392008],
#        [0.87354578],
#        [0.22862924],
#        [0.06423875],
#        [0.40566515],
#        [0.44360142],
#        [0.63328275],
#        [0.70915529],
#        [0.53211937],
#        [0.20333839],
#        [0.35508346],
#        [0.57005564],
#        [0.60799191],
#        [0.12746586],
#        [0.48153768],
#        [0.40566515],
#        [0.64592817],
#        [0.32979262],
#        [0.48153768],
#        [0.19069297],
#        [0.63328275],
#        [0.59534648],
#        [0.3803743 ],
#        [0.58270106],
#        [0.40566515],
#        [0.69650986],
#        [0.22862924],
#        [0.31714719]])

# %% [markdown]
# ### standared scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
Sc=StandardScaler()

# %%
x_fare=df[['fare']].values
x_fare_transformed= Sc.fit_transform(x_fare)
x_fare_transformed
# Out:
# array([[-1.00110129e-01],
#        [-3.38484771e-01],
#        [-3.54707823e-01],
#        [-8.15671915e-01],
#        [-6.86542977e-01],
#        [-8.64177202e-01],
#        [-5.69212621e-01],
#        [ 2.41320703e+00],
#        [-2.87169016e-02],
#        [-2.22082571e-01],
#        [ 5.97174125e-02],
#        [-8.96951044e-01],
#        [-9.34313224e-01],
#        [ 2.41320703e+00],
#        [-2.32625261e-01],
#        [-5.80300668e-01],
#        [-2.04003209e-01],
#        [-2.13978472e-02],
#        [-3.52905262e-01],
#        [ 2.21028188e+00],
#        [-8.64177202e-01],
#        [-2.13978472e-02],
#        [-6.90039290e-01],
#        [-3.38484771e-01],
#        [ 3.67414220e-03],
#        [-6.93753222e-01],
#        [-1.61506023e-01],
#        [-5.95431695e-01],
#        [-6.32193458e-01],
#        [-6.58193603e-01],
#        [-5.23329242e-01],
#        [-6.93753222e-01],
#        [-6.71194331e-01],
#        [ 8.86218655e-01],
#        [-8.97442652e-01],
#        [-6.28205537e-01],
#        [ 4.50381613e-01],
#        [-3.44523240e-02],
#        [ 1.45257141e-01],
#        [ 5.97174125e-02],
#        [ 1.45257141e-01],
#        [-3.45639957e-01],
#        [-8.97442652e-01],
#        [-6.86542977e-01],
#        [ 9.93737617e-02],
#        [ 9.57343382e-03],
#        [-1.03460118e+00],
#        [ 9.77221128e-01],
#        [ 7.43488572e-01],
#        [-6.45247935e-01],
#        [-1.26039698e-02],
#        [ 1.59404953e-01],
#        [-8.65815894e-01],
#        [ 9.52149138e-01],
#        [ 2.21028188e+00],
#        [ 9.52149138e-01],
#        [ 3.93027389e-01],
#        [-2.88285733e-01],
#        [ 5.55656222e-02],
#        [ 2.40501357e+00],
#        [ 1.12672491e+00],
#        [ 7.28631534e-01],
#        [ 7.43488572e-01],
#        [-8.64177202e-01],
#        [-2.74520719e-01],
#        [-6.60979380e-01],
#        [ 9.77221128e-01],
#        [-1.61506023e-01],
#        [ 7.28631534e-01],
#        [-6.93753222e-01],
#        [ 2.41320703e+00],
#        [-8.64177202e-01],
#        [-3.13576651e-01],
#        [-4.81085286e-02],
#        [-1.26110273e-01],
#        [-3.07786169e-01],
#        [ 1.73806588e+00],
#        [ 5.38543249e-01],
#        [ 4.50381613e-01],
#        [-8.15671915e-01],
#        [ 1.45257141e-01],
#        [-9.29069410e-01],
#        [-6.86542977e-01],
#        [-3.01778068e-01],
#        [ 5.38543249e-01],
#        [ 2.41320703e+00],
#        [ 3.85232242e-02],
#        [-6.34760306e-01],
#        [-6.70811532e-01],
#        [ 1.33513618e-01],
#        [-6.86542977e-01],
#        [-6.86542977e-01],
#        [-5.29884010e-01],
#        [-8.53798382e-01],
#        [ 1.59404953e-01],
#        [ 1.45257141e-01],
#        [-6.45247935e-01],
#        [-6.34760306e-01],
#        [-8.56098860e-03],
#        [ 9.52149138e-01],
#        [ 9.93737617e-02],
#        [ 3.93027389e-01],
#        [-6.89984230e-01],
#        [-5.88604248e-01],
#        [-8.96951044e-01],
#        [ 1.91140520e-01],
#        [-2.74520719e-01],
#        [-6.86542977e-01],
#        [-3.85679104e-01],
#        [-1.03824061e-01],
#        [ 3.60581285e-01],
#        [ 4.19027533e-01],
#        [-5.15463520e-01],
#        [ 9.57343382e-03],
#        [-3.59732709e-01],
#        [-6.88673276e-01],
#        [-3.01778068e-01],
#        [ 4.19027533e-01],
#        [-5.08581013e-01],
#        [ 9.57343382e-03],
#        [ 3.67414220e-03],
#        [-8.56098860e-03],
#        [-2.88285733e-01],
#        [ 9.77221128e-01],
#        [-5.23329242e-01],
#        [-3.45639957e-01],
#        [-6.10890461e-01],
#        [-1.26039698e-02],
#        [-6.41315074e-01],
#        [-6.34760306e-01],
#        [-1.26110273e-01],
#        [-2.87169016e-02],
#        [-5.69212621e-01],
#        [ 4.50381613e-01],
#        [-6.99160906e-01],
#        [-3.52905262e-01],
#        [ 5.68179738e+00],
#        [-2.87169016e-02],
#        [ 1.73593558e+00],
#        [-2.87357577e-01],
#        [ 4.19027533e-01],
#        [-9.34313224e-01],
#        [ 1.94814621e+00],
#        [-6.89984230e-01],
#        [-6.89984230e-01],
#        [-3.85624044e-01],
#        [-3.52905262e-01],
#        [-9.34313224e-01],
#        [ 1.94814621e+00],
#        [-8.96951044e-01],
#        [-3.38484771e-01],
#        [ 1.73593558e+00],
#        [ 5.68179738e+00],
#        [-9.14195718e-04],
#        [ 2.40501357e+00],
#        [-1.03824061e-01],
#        [-3.38484771e-01],
#        [-8.71059709e-01],
#        [ 9.93737617e-02],
#        [ 5.38543249e-01],
#        [-1.26039698e-02],
#        [-8.96951044e-01],
#        [ 1.73593558e+00],
#        [-2.87357577e-01],
#        [-6.41315074e-01],
#        [ 3.67414220e-03],
#        [-6.94681377e-01],
#        [ 5.38543249e-01],
#        [-1.03460118e+00],
#        [-3.38484771e-01],
#        [ 1.91140520e-01],
#        [-8.71059709e-01],
#        [ 5.55656222e-02],
#        [-5.18085427e-01],
#        [-6.86542977e-01],
#        [-6.94681377e-01],
#        [-3.72624627e-01],
#        [-3.45639957e-01],
#        [-9.69053497e-01],
#        [ 5.55656222e-02],
#        [-6.41315074e-01],
#        [-6.41315074e-01]])

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#      survived  pclass   age  sibsp  parch     fare  adult_male  alone  \
# 1           1       1  38.0      1      0  71.2833       False  False
# 3           1       1  35.0      1      0  53.1000       False  False
# 6           0       1  54.0      0      0  51.8625        True   True
# 10          1       3   4.0      1      1  16.7000       False  False
# 11          1       1  58.0      0      0  26.5500       False   True
# ..        ...     ...   ...    ...    ...      ...         ...    ...
# 871         1       1  47.0      1      1  52.5542       False  False
# 872         0       1  33.0      0      0   5.0000        True   True
# 879         1       1  56.0      0      1  83.1583       False  False
# 887         1       1  19.0      0      0  30.0000       False   True
# 889         1       1  26.0      0      0  30.0000        True   True
#
#      sex_male  embarked_Q  ...  who_woman  deck_B  deck_C  deck_D  deck_E  \
# 1           0           0  ...          1       0       1       0       0
# 3           0           0  ...          1       0       1       0       0
# 6           1           0  ...          0       0       0       0       1
# 10          0           0  ...          0       0       0       0       0
# 11          0           0  ...          1       0       1       0       0
# ..        ...         ...  ...        ...     ...     ...     ...     ...
# 871         0           0  ...          1       0       0       1       0
# 872         1           0  ...          0       1       0       0       0
# 879         0           0  ...          1       0       1       0       0
# 887         0           0  ...          1       1       0       0       0
# 889         1           0  ...          0       0       1       0       0
#
#      deck_F  deck_G  embark_town_Queenstown  embark_town_Southampton  \
# 1         0       0                       0                        0
# 3         0       0                       0                        1
# 6         0       0                       0                        1
# 10        0       1                       0                        1
# 11        0       0                       0                        1
# ..      ...     ...                     ...                      ...
# 871       0       0                       0                        1
# 872       0       0                       0                        1
# 879       0       0                       0                        0
# 887       0       0                       0                        1
# 889       0       0                       0                        0
#
#      alive_yes
# 1            1
# 3            1
# 6            0
# 10           1
# 11           1
# ..         ...
# 871          1
# 872          0
# 879          1
# 887          1
# 889          1
#
# [182 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# survived                   0
# pclass                     0
# age                        0
# sibsp                      0
# parch                      0
# fare                       0
# adult_male                 0
# alone                      0
# sex_male                   0
# embarked_Q                 0
# embarked_S                 0
# class_Second               0
# class_Third                0
# who_man                    0
# who_woman                  0
# deck_B                     0
# deck_C                     0
# deck_D                     0
# deck_E                     0
# deck_F                     0
# deck_G                     0
# embark_town_Queenstown     0
# embark_town_Southampton    0
# alive_yes                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 1 to 889
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   survived                 182 non-null    int64
#  1   pclass                   182 non-null    int64
#  2   age                      182 non-null    float64
#  3   sibsp                    182 non-null    int64
#  4   parch                    182 non-null    int64
#  5   fare                     182 non-null    float64
#  6   adult_male               182 non-null    bool
#  7   alone                    182 non-null    bool
#  8   sex_male                 182 non-null    uint8
#  9   embarked_Q               182 non-null    uint8
#  10  embarked_S               182 non-null    uint8
#  11  class_Second             182 non-null    uint8
#  12  class_Third              182 non-null    uint8
#  13  who_man                  182 non-null    uint8
#  14  who_woman                182 non-null    uint8
#  15  deck_B                   182 non-null    uint8
#  16  deck_C                   182 non-null    uint8
#  17  deck_D                   182 non-null    uint8
#  18  deck_E                   182 non-null    uint8
#  19  deck_F                   182 non-null    uint8
#  20  deck_G                   182 non-null    uint8
#  21  embark_town_Queenstown   182 non-null    uint8
#  22  embark_town_Southampton  182 non-null    uint8
#  23  alive_yes                182 non-null    uint8
# dtypes: bool(2), float64(2), int64(4), uint8(16)
# memory usage: 13.2 KB

# %%
# %matplotlib inline

# %% [markdown]
# ### Kde plot

# %%
plt.figure(figsize=(6,8))
sns.kdeplot(data=df.age)
plt.show()

# %% [markdown]
# ## Histplot

# %%
plt.figsize=(5,6)
sns.histplot(df.fare)
plt.show()

# %% [markdown]
# ## Box plot

# %%
plt.figsize=(8,6)
sns.boxplot('age',data=df)
plt.show()

# %% [markdown]
# ## multi variate analysis

# %% [markdown]
# # Line plot

# %%
plt.figsize=(10,9)
sns.lineplot('age','fare',data=df)
plt.title("Age vs Fare")
plt.show()

# %% [markdown]
# ## bar  CHART
