# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Car_sales.csv')
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
df.Latest_Launch.unique()
# Out:
# array(['2/2/2012', '6/3/2011', '3/10/2011', '10/8/2011', '8/9/2011',
#        '2/27/2012', '1/29/2012', '4/4/2011', '11/2/2011', '9/3/2011',
#        '3/23/2012', '7/23/2011', '2/23/2012', '11/27/2011', '9/28/2011',
#        '8/17/2011', '3/19/2012', '5/24/2011', '12/22/2011', '10/23/2011',
#        '5/12/2012', '9/11/2011', '4/13/2012', '1/16/2012', '11/17/2011',
#        '6/6/2012', '10/6/2011', '5/8/2012', '12/12/2011', '7/1/2012',
#        '10/31/2011', '8/7/2011', '3/6/2012', '1/6/2012', '7/26/2012',
#        '11/25/2011', '9/1/2011', '3/31/2012', '1/31/2012', '8/20/2012',
#        '12/20/2011', '9/26/2011', '4/25/2012', '2/25/2012', '9/14/2012',
#        '1/14/2012', '8/16/2012', '10/21/2011', '5/20/2012', '3/21/2012',
#        '10/9/2012', '2/8/2012', '9/10/2012', '11/15/2011', '6/14/2012',
#        '4/15/2012', '3/4/2012', '10/5/2012', '12/10/2011', '7/9/2012',
#        '5/10/2012', '3/29/2012', '8/3/2012', '6/4/2012', '4/23/2012',
# ...

# %%
df['Latest_Launch']=pd.to_datetime(df.Latest_Launch)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df['Year']=pd.DatetimeIndex(df.Latest_Launch).year
df['Month']=pd.DatetimeIndex(df.Latest_Launch).month
df['Day']=pd.DatetimeIndex(df.Latest_Launch).day
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.Month.replace({
    1:"Januvary",
    2:"Februvary",
    3:"March",
    4:"April",
    5:"May",
    6:"June",
    7:"July",
    8:"Auguest",
    9:"September",
    10:"October",
    11:"November",
    12:"December"
},inplace=True)
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
# ...

# %%
df.Fuel_efficiency=df.Fuel_efficiency.astype(int)
df.head(10)
# Out:
#    Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura  Integra              16.919               16.360
# 1         Acura       TL              39.384               19.875
# 3         Acura       RL               8.588               29.725
# 4          Audi       A4              20.397               22.255
# 5          Audi       A6              18.780               23.555
# 6          Audi       A8               1.380               39.000
# 8           BMW     328i               9.231               28.675
# 9           BMW     528i              17.527               36.125
# 10        Buick  Century              91.561               12.475
# 11        Buick    Regal              39.350               13.740
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0     Passenger              21.500          1.8       140.0      101.2
# 1     Passenger              28.400          3.2       225.0      108.1
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le=LabelEncoder()

# %%
df["Le_Vehicle"] = Le.fit_transform(df.Vehicle_type)
df["Le_Manufacture"]=Le.fit_transform(df.Manufacturer)
df["Le_Model"]=Le.fit_transform(df.Model)

# %%
df.sample(10)
# Out:
#     Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 81    Mitsubishi       Galant              55.616               10.595
# 41         Dodge    Ram Wagon              16.767               15.510
# 115     Plymouth       Breeze               5.240                9.800
# 93    Mercedes-B      E-Class              27.602               41.450
# 31      Chrysler       Cirrus              32.306               12.640
# 35         Dodge         Neon              76.034                7.750
# 76       Lincoln  Continental              13.798               20.525
# 139       Toyota       Celica              33.269               15.445
# 120      Pontiac     Firebird              19.911               17.805
# 52          Ford     Explorer             276.747               16.640
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 81     Passenger              17.357          2.4       145.0      103.7
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.Horsepower.plot.hist(figsize=(6,3),cmap='brg');

# %%
df.Sales_in_thousands.plot.box(figsize=(4,3), cmap='gist_earth');

# %%
df.Horsepower.plot.box(figsize=(4,3),cmap='Blues_r');

# %%
df.plot.box(figsize=(22,4),subplots=True);

# %%
df.plot.hist(figsize=(6,18), subplots=True);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.sort_values(by='__year_resale_value').plot.line('__year_resale_value','Price_in_thousands', figsize=(6,3), cmap='inferno');

# %%
df.Manufacturer.value_counts().plot.bar(figsize=(6,2), cmap='PuBuGn_r');

# %%
df.sort_values(by='Price_in_thousands')[:20].plot.bar('Manufacturer','Price_in_thousands',figsize=(6,3),cmap='gist_rainbow_r');

# %%
df.plot.area('Manufacturer',"Price_in_thousands",figsize=(6,3), cmap='viridis_r');

# %%
df.sort_values(by='Price_in_thousands')[:5].plot.barh('Model','Power_perf_factor',figsize=(7,4),cmap='gnuplot');

# %%
df.plot.box(figsize=(22,5));

# %%
df.sort_values(by='Engine_size',ascending=False)[:10].Engine_size.plot.pie()
# Out:
# <AxesSubplot:ylabel='Engine_size'>

# %%
df.plot.kde(figsize=(10,3.8));
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6800\4095052173.py in <module>
# ----> 1 df.plot.kde(figsize=(10,3.8));
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in kde(self, bw_method, ind, **kwargs)
#    1452             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1453         """
# -> 1454         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1455
#    1456     density = kde
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %%
df1=pd.read_csv('Car_sales.csv')
df1
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df1.plot.kde(figsize=(10,3.8));

# %%
df1.plot.kde(figsize=(10,5),subplots=True);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.plot.hexbin('Curb_weight','Fuel_capacity',gridsize=16, cmap='gnuplot');

# %%
df.plot.hexbin('Curb_weight','Fuel_capacity',gridsize=16, cmap='gist_rainbow');
