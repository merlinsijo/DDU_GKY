# %% [markdown]
# ### Boolean masking

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("netflix_titles_2021 (1).csv")
df.sample(10)
# Out:
#      show_id     type                                   title  \
# 4264   s4265  TV Show                  People Just Do Nothing
# 5505   s5506    Movie                                    Loev
# 3413   s3414    Movie                        Verses of Love 2
# 6676   s6677  TV Show                                 El Clon
# 2795   s2796  TV Show  Tiger King: Murder, Mayhem and Madness
# 948     s949    Movie                                  Swiped
# 4348   s4349    Movie                    SDU: Sex Duties Unit
# 5162   s5163    Movie                       Saving Capitalism
# 1548   s1549  TV Show                           The Challenge
# 3932   s3933    Movie    Sarvam Thaala Mayam (Telugu Version)
#
#                           director  \
# 4264                           NaN
# 5505               Sudhanshu Saria
# 3413            Guntur Soeharjanto
# 6676                           NaN
# 2795  Eric Goode, Rebecca Chaiklin
# 948            Ann Deborah Fishman
# ...

# %%
df['release_year']
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2007
# 8803    2018
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 8807, dtype: int64

# %% [markdown]
# # Boolean masking

# %%
release_year=pd.Series([2020,2021,2021,2020,2018,2019,2015,2022])
BM=[True,False,True,True,False,False,True,False]
release_year[BM]
# Out:
# 0    2020
# 2    2021
# 3    2020
# 6    2015
# dtype: int64

# %%
df2=df.query('release_year==2020&type=="Movie"')
df2.head(10)
# Out:
#     show_id   type                                              title  \
# 0        s1  Movie                               Dick Johnson Is Dead
# 16      s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78      s79  Movie                                     Tughlaq Durbar
# 84      s85  Movie                               Omo Ghetto: the Saga
# 103    s104  Movie                                     Shadow Parties
# 119    s120  Movie                                     Here and There
# 126    s127  Movie                                            Shikara
# 227    s228  Movie                                        Really Love
# 229    s230  Movie                                       The Old Ways
# 250    s251  Movie                                     A Faraway Land
#
#                                           director  \
# 0                                  Kirsten Johnson
# 16   Pedro de Echave García, Pablo Azorín Williams
# ...

# %% [markdown]
# #### display the count of movies released in the year 2020 in nation

# %%
BM = df.release_year==2020

# %%
df[BM].country.value_counts()
# Out:
# United States                             336
# India                                      75
# United Kingdom                             44
# South Korea                                28
# Canada                                     26
#                                          ...
# Germany, Czech Republic                     1
# United States, Bulgaria                     1
# United Kingdom, France, Germany, Spain      1
# Thailand, United States                     1
# United States, South Korea, China           1
# Name: country, Length: 107, dtype: int64

# %%
BM = df.release_year <= 1990

# %%
df[BM].country.value_counts()
# Out:
# United States                                                  120
# India                                                           49
# Hong Kong                                                       20
# Egypt                                                           11
# Poland                                                           7
# United Kingdom                                                   6
# United States, United Kingdom                                    5
# United Kingdom, United States                                    5
# Japan                                                            3
# Argentina                                                        2
# Italy, United States                                             2
# Australia, United States                                         2
# Lebanon, Canada, France                                          2
# Hong Kong, China                                                 1
# ...

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# ### count of movies released in each year

# %%
BM=df.type=="Movie"

# %%
df[BM].release_year.value_counts()
# Out:
# 2017    767
# 2018    767
# 2016    658
# 2019    633
# 2020    517
#        ...
# 1966      1
# 1961      1
# 1946      1
# 1963      1
# 1947      1
# Name: release_year, Length: 73, dtype: int64

# %%
BM = (df['type'] == "movie") & (df['release_year'] > 2020)

# %%
df[BM].country.value_counts()
# Out:
# Series([], Name: country, dtype: int64)
